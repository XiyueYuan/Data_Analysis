# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col = 'ResponseId')
df.head(10)
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
# 6           I am a developer by profession  45-54 years old
# 7           I am a developer by profession  25-34 years old
# 8           I am a developer by profession  35-44 years old
# 9           I am a developer by profession  25-34 years old
# 10          I am a developer by profession  25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %% [markdown]
# To get the specific column after filtering
# - first create a variable contains the selected dataframe
# - then put into loc to filter

# %%
high_salary = df['ConvertedCompYearly'] >= 10000000
df.loc[high_salary, ['LearnCodeChoose', 'LearnCode', 'Age']]
# Out:
#                                               LearnCodeChoose  \
# ResponseId
# 28701       No, I am not new to coding and did not learn n...
# 34268       Yes, I am not new to coding but am learning ne...
# 35354       No, I am not new to coding and did not learn n...
# 43144       Yes, I am not new to coding but am learning ne...
# 45972       Yes, I am not new to coding but am learning ne...
# 48429       Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode              Age
# ResponseId
# 28701                                                     NaN  35-44 years old
# 34268       Other online resources (e.g. standard search, ...  55-64 years old
# 35354                                                     NaN  35-44 years old
# 43144                                 Other (please specify):  18-24 years old
# 45972                        Colleague or on-the-job training  55-64 years old
# ...

# %% [markdown]
# Using `isin` as `in` function to filter

# %%
countries = ['United States', 'India', 'United Kindom', 'Germany']
filt = df['Country'].isin(countries)
df.loc[filt, 'Country']
# Out:
# ResponseId
# 14         India
# 16         India
# 19       Germany
# 36       Germany
# 47         India
#           ...
# 49046      India
# 49047      India
# 49075      India
# 49081      India
# 49090      India
# Name: Country, Length: 5564, dtype: object

# %% [markdown]
# `str.contains` will check if each `'LanguageHaveWorkedWith'` contains `str` `'Python'` and return a bool value
#
# `na = False` by default

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na = False)
df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 5        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
# 8        Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 9                                        Java;Python;Scala
# 16       Ada;Assembly;C;C#;C++;COBOL;Dart;Delphi;Elixir...
# 18                          HTML/CSS;JavaScript;Python;SQL
#                                ...
# 49062    C;Go;HTML/CSS;JavaScript;MATLAB;MicroPython;Py...
# 49089                                           Python;SQL
# 49090    C;C#;C++;HTML/CSS;Java;JavaScript;PHP;PowerShe...
# 49106    C++;Dart;GDScript;HTML/CSS;JavaScript;PHP;Powe...
# 49107    Bash/Shell (all shells);Delphi;PowerShell;Pyth...
# Name: LanguageHaveWorkedWith, Length: 18444, dtype: object

# %% [markdown]
# Rename the column name by using `{}`

# %%
df = df.rename(columns = {'LanguageHaveWorkedWith': 'LanguageUsed'})
df['LanguageUsed']
# Out:
# ResponseId
# 1                         Bash/Shell (all shells);Dart;SQL
# 2                                                     Java
# 3                      Dart;HTML/CSS;JavaScript;TypeScript
# 4                                          Java;Kotlin;SQL
# 5        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#                                ...
# 49119                                                  NaN
# 49120                                                  NaN
# 49121                                                  NaN
# 49122                                               C#;SQL
# 49123                                                  NaN
# Name: LanguageUsed, Length: 49123, dtype: object

# %%
df['Employment']
# Out:
# ResponseId
# 1                                                 Employed
# 2                                                 Employed
# 3        Independent contractor, freelancer, or self-em...
# 4                                                 Employed
# 5        Independent contractor, freelancer, or self-em...
#                                ...
# 49119                                             Employed
# 49120                                             Employed
# 49121                                             Employed
# 49122                                             Employed
# 49123                                             Employed
# Name: Employment, Length: 49123, dtype: object

# %% [markdown]
# Now, if i want to convert all `'Employed'` to `True`, use the `repr()` to check the exact str in it, because it might be `'Employed '` with an extra space after, and use `type()` to check the type, because it might be non-str elements.

# %%
print(type(df['Employment'].iloc[1]))
print(repr(df['Employment'].iloc[1:10]))
# Out:
# <class 'str'>
# ResponseId
# 2                                              Employed
# 3     Independent contractor, freelancer, or self-em...
# 4                                              Employed
# 5     Independent contractor, freelancer, or self-em...
# 6     Independent contractor, freelancer, or self-em...
# 7     Independent contractor, freelancer, or self-em...
# 8                                              Employed
# 9                                              Employed
# 10                                             Employed
# Name: Employment, dtype: object

# %% [markdown]
# Then use `map(lambda x:)` to modify every element in the `Employment` column list

# %%
df['Employment'] = df['Employment'].map(lambda x: True if x == 'Employed' else False)
df['Employment']
# Out:
# ResponseId
# 1         True
# 2         True
# 3        False
# 4         True
# 5        False
#          ...
# 49119     True
# 49120     True
# 49121     True
# 49122     True
# 49123     True
# Name: Employment, Length: 49123, dtype: bool

# %%
df['Country']
# Out:
# ResponseId
# 1            Ukraine
# 2        Netherlands
# 3            Ukraine
# 4            Ukraine
# 5            Ukraine
#             ...
# 49119            NaN
# 49120            NaN
# 49121            NaN
# 49122         France
# 49123          Italy
# Name: Country, Length: 49123, dtype: object

# %% [markdown]
# Using `sort` function to sort people salary within each country

# %%
df = df.rename(columns = {'ConvertedCompYearly': 'Salary'})
df['Salary']
# Out:
# ResponseId
# 1         61256.0
# 2        104413.0
# 3         53061.0
# 4         36197.0
# 5         60000.0
#            ...
# 49119         NaN
# 49120         NaN
# 49121         NaN
# 49122         NaN
# 49123         NaN
# Name: Salary, Length: 49123, dtype: float64

# %%
test = df.sort_values(by = ['Country', 'Salary'], ascending = [True, True])
test[['Salary', 'Country']].head(10)
# Out:
#              Salary      Country
# ResponseId
# 7925          282.0  Afghanistan
# 6010          986.0  Afghanistan
# 38609        1000.0  Afghanistan
# 7167         5200.0  Afghanistan
# 45925        7042.0  Afghanistan
# 7077         8450.0  Afghanistan
# 40307        9858.0  Afghanistan
# 40967       65000.0  Afghanistan
# 6836            NaN  Afghanistan
# 15708           NaN  Afghanistan

# %% [markdown]
# `nlargest(int)` filt the largest one then using `loc[filt.index]` select other columns, here need  `filt.index1` because filt contains integer not boolean

# %%
filt = df['Salary'].nlargest(10)
df.loc[filt.index, 'Country']
# Out:
# ResponseId
# 34268        United States of America
# 28701                         Ukraine
# 43144                          Poland
# 35354    Iran, Islamic Republic of...
# 45972                     Netherlands
# 48429                         Ukraine
# 24901                           India
# 10026        United States of America
# 37353                         Ukraine
# 30729                          Brazil
# Name: Country, dtype: object

# %% [markdown]
# Or you can simply display all, or `nsmallest`

# %%
df.nlargest(10, 'Salary')
# Out:
#                                                    MainBranch  \
# ResponseId
# 34268                             I code primarily as a hobby
# 28701                          I am a developer by profession
# 43144                             I code primarily as a hobby
# 35354                          I am a developer by profession
# 45972       I work with developers or my work supports dev...
# 48429                             I code primarily as a hobby
# 24901                          I am a developer by profession
# 10026                          I am a developer by profession
# 37353                          I am a developer by profession
# 30729                          I am a developer by profession
#
#                         Age                                          EdLevel  \
# ResponseId
# 34268       55-64 years old              Associate degree (A.A., A.S., etc.)
# 28701       35-44 years old  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df['Salary'].head(15)
df['Salary'].median()
# Out:
# np.float64(75383.5)

# %% [markdown]
# Statistic

# %%
df['Employment'].value_counts()
# Out:
# Employment
# True     33709
# False    15414
# Name: count, dtype: int64

# %% [markdown]
# `read_csv` import new data

# %%
df_new = pd.read_csv('data/stack-overflow-developer-survey-2019/survey_results_public.csv')
df_new['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
filt = df_new['Country'] == 'United States'
df_new.loc[filt, 'SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: count, dtype: int64

# %%
countries = df_new.groupby('Country')
countries['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %% [markdown]
# `normalize = True` returns in proportion

# %%
countries['SocialMedia'].value_counts(normalize = True).loc['United States']
df_new.groupby('Country')['SocialMedia'].value_counts(normalize = True).loc['United States']
# Out:
# SocialMedia
# Reddit                      0.284346
# Twitter                     0.173002
# Facebook                    0.141874
# YouTube                     0.122867
# I don't use social media    0.092338
# Instagram                   0.082410
# LinkedIn                    0.050883
# WhatsApp                    0.030380
# Snapchat                    0.016263
# WeChat 微信                   0.004639
# VK ВКонта́кте               0.000449
# Weibo 新浪微博                  0.000399
# Hello                       0.000100
# Youku Tudou 优酷              0.000050
# Name: proportion, dtype: float64

# %%
countries['ConvertedComp'].median().loc[['Germany', 'China', 'United States', 'India']]
# Out:
# Country
# Germany           63016.0
# China             28464.0
# United States    110000.0
# India             10080.0
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# Use `agg([...])` to aggregate multiple statistics

# %%
countries['ConvertedComp'].agg(['median', 'mean']).loc[['Germany', 'China', 'United States', 'India']]
# Out:
#                  median           mean
# Country
# Germany         63016.0  109256.884066
# China           28464.0   57430.421053
# United States  110000.0  249546.254589
# India           10080.0   28057.664916

# %% [markdown]
# Use `.size()` to access numbers in each group

# %%
filt = df_new['LanguageWorkedWith'].str.contains('Python', na = False)
df_new[filt].groupby('Country').size().loc['United States']
# Out:
# np.int64(10083)

# %%
df_new[filt].groupby('Country').size().sort_values(ascending = False)
# Out:
# Country
# United States     10083
# India              3105
# Germany            2451
# United Kingdom     2384
# Canada             1558
#                   ...
# Niger                 1
# Togo                  1
# Timor-Leste           1
# Fiji                  1
# Mozambique            1
# Length: 162, dtype: int64

# %% [markdown]
# Proportion

# %%
count = df_new[filt].groupby('Country').size()
(count / count.sum()).sort_values(ascending = False)
# Out:
# Country
# United States     0.276679
# India             0.085202
# Germany           0.067256
# United Kingdom    0.065417
# Canada            0.042752
#                     ...
# Niger             0.000027
# Togo              0.000027
# Timor-Leste       0.000027
# Fiji              0.000027
# Mozambique        0.000027
# Length: 162, dtype: float64

# %% [markdown]
# `filt` get people who know python, `num_respondents` get the number of respondents groupby countries, `python_users` to filter people who know python and then groupby countries.

# %%
filt = df_new['LanguageWorkedWith'].str.contains('Python', na = False)
num_respondents = df_new.groupby('Country').size()
python_users = df_new[filt].groupby('Country').size()
proportion = ((python_users / num_respondents) * 100)
python_df = pd.concat(
    [num_respondents, python_users, proportion], 
    axis = 'columns',
    keys=['TotalRespondents', 'PythonUsers', 'PythonRatio'],
)
python_df.sort_values(by = 'PythonRatio', ascending = False, inplace = True)
python_df['Ratio_disply'] = python_df['PythonRatio'].map(lambda x: f'{x:.1f}%' if pd.notna(x) else '')
python_df.head(50)
# Out:
#                                   TotalRespondents  PythonUsers  PythonRatio  \
# Country
# Sao Tome and Principe                            1          1.0   100.000000
# Dominica                                         1          1.0   100.000000
# Niger                                            1          1.0   100.000000
# Timor-Leste                                      1          1.0   100.000000
# Turkmenistan                                     7          6.0    85.714286
# Mauritania                                       7          5.0    71.428571
# Guyana                                           3          2.0    66.666667
# Guinea                                           3          2.0    66.666667
# Bahamas                                          3          2.0    66.666667
# Uganda                                          72         47.0    65.277778
# Iceland                                         49         30.0    61.224490
# ...
